# %% [markdown]
# # Q1

# %%
import pandas as pd

penguins = pd.read_csv("../datasets/penguins.csv")

columns = ["Body Mass (g)", "Flipper Length (mm)", "Culmen Length (mm)"]
target_name = "Species"

# Remove lines with missing values for the columns of interest
penguins_non_missing = penguins[columns + [target_name]].dropna()

data = penguins_non_missing[columns]
target = penguins_non_missing[target_name]

# %%
target.value_counts() # target.nunique()
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          151
# Gentoo penguin (Pygoscelis papua)            123
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64

# %% [markdown]
# # Q2

# %%
data.describe()
# Out:
#        Body Mass (g)  Flipper Length (mm)  Culmen Length (mm)
# count     342.000000           342.000000          342.000000
# mean     4201.754386           200.915205           43.921930
# std       801.954536            14.061714            5.459584
# min      2700.000000           172.000000           32.100000
# 25%      3550.000000           190.000000           39.225000
# 50%      4050.000000           197.000000           44.450000
# 75%      4750.000000           213.000000           48.500000
# max      6300.000000           231.000000           59.600000

# %%
pd.DataFrame(target.value_counts())
# Out:
#                                            count
# Species
# Adelie Penguin (Pygoscelis adeliae)          151
# Gentoo penguin (Pygoscelis papua)            123
# Chinstrap penguin (Pygoscelis antarctica)     68

# %% [markdown]
# # Q3

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
model = Pipeline(steps=[
    ("preprocessor", StandardScaler()),
    ("classifier", KNeighborsClassifier(n_neighbors=5)),
])

# %%
from sklearn.model_selection import cross_val_score

cv_results = cross_val_score(
    model, data, target, cv=10, scoring="balanced_accuracy"
)

# %%
print(f"The cross-validation score is {cv_results.mean():.3f} ± {cv_results.std():.3f}")
# Out:
# The cross-validation score is 0.952 ± 0.040

# %% [markdown]
# # Q4

# %%
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor', StandardScaler()),
#   ('classifier', KNeighborsClassifier())],
#  'transform_input': None,
#  'verbose': False,
#  'preprocessor': StandardScaler(),
#  'classifier': KNeighborsClassifier(),
#  'preprocessor__copy': True,
#  'preprocessor__with_mean': True,
#  'preprocessor__with_std': True,
#  'classifier__algorithm': 'auto',
#  'classifier__leaf_size': 30,
#  'classifier__metric': 'minkowski',
#  'classifier__metric_params': None,
#  'classifier__n_jobs': None,
#  'classifier__n_neighbors': 5,
#  'classifier__p': 2,
#  'classifier__weights': 'uniform'}

# %%
for i in (5, 51, 101):
    model.set_params(classifier__n_neighbors=i)
    cv_results = cross_val_score(model, data, target, cv=10, scoring="balanced_accuracy")
    print(f"The cross-validation score for n_neighbors={i} is:\n{pd.DataFrame(cv_results)}")
# Out:
# The cross-validation score for n_neighbors=5 is:
#           0
# 0  1.000000
# 1  1.000000
# 2  1.000000
# 3  0.918803
# 4  0.882540
# 5  0.952381
# 6  0.977778
# 7  0.930159
# 8  0.907937
# 9  0.952381
# The cross-validation score for n_neighbors=51 is:
#           0
# 0  0.952381
# 1  0.977778
# 2  1.000000
# 3  0.863248
# 4  0.882540
# 5  0.952381
# 6  0.955556
# 7  0.952381
# 8  0.930159
# 9  0.952381
# The cross-validation score for n_neighbors=101 is:
#           0
# 0  0.857143
# 1  0.952381
# 2  0.944444
# 3  0.863248
# 4  0.834921
# 5  0.857143
# 6  0.834921
# 7  0.882540
# 8  0.834921
# 9  0.904762

# %%
model_raw = KNeighborsClassifier(n_neighbors=5)
cv_results_raw = cross_val_score(
    model_raw, data, target, cv=10
)

# %%
pd.DataFrame(cv_results_raw)
print(f"The cross-validation score when raw is:\n{pd.DataFrame(cv_results_raw)}")
# Out:
# The cross-validation score when raw is:
#           0
# 0  0.742857
# 1  0.800000
# 2  0.794118
# 3  0.794118
# 4  0.647059
# 5  0.764706
# 6  0.882353
# 7  0.794118
# 8  0.911765
# 9  0.852941

# %% [markdown]
# # Q5

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer


all_preprocessors = [
    None,
    StandardScaler(),
    MinMaxScaler(),
    QuantileTransformer(n_quantiles=100),
    PowerTransformer(method="box-cox"),
]

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "preprocessor": all_preprocessors,
    "classifier__n_neighbors": [5, 51, 101]
}

# %%
model_grid_search = GridSearchCV(
    model,
    param_grid=param_grid,
    cv=10
)

# %%
model_grid_search.fit(data, target)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor', StandardScaler()),
#                                        ('classifier',
#                                         KNeighborsClassifier(n_neighbors=101))]),
#              param_grid={'classifier__n_neighbors': [5, 51, 101],
#                          'preprocessor': [None, StandardScaler(),
#                                           MinMaxScaler(),
#                                           QuantileTransformer(n_quantiles=100),
#                                           PowerTransformer(method='box-cox')]})

# %%
model_grid_search.best_params_
# Out:
# {'classifier__n_neighbors': 5, 'preprocessor': StandardScaler()}

# %%
pd.DataFrame(model_grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002029      0.000342         0.002472        0.000293
# 1        0.002962      0.000347         0.002560        0.000297
# 2        0.002742      0.000212         0.002495        0.000260
# 3        0.003868      0.000632         0.003106        0.001576
# 4        0.049755      0.007000         0.002839        0.000365
# 5        0.001693      0.000173         0.002325        0.000300
# 6        0.002666      0.000257         0.002503        0.000309
# 7        0.002701      0.000403         0.002492        0.000238
# 8        0.003252      0.000206         0.002620        0.000290
# 9        0.045536      0.006625         0.002696        0.000069
# 10       0.001654      0.000069         0.002393        0.000155
# 11       0.002521      0.000070         0.002530        0.000115
# 12       0.002573      0.000169         0.002558        0.000109
# 13       0.003242      0.000121         0.002630        0.000056
# 14       0.044371      0.006132         0.002833        0.000060
#
#     param_classifier__n_neighbors                    param_preprocessor  \
# 0                               5                                  None
# 1                               5                      StandardScaler()
# 2                               5                        MinMaxScaler()
# 3                               5  QuantileTransformer(n_quantiles=100)
# 4                               5    PowerTransformer(method='box-cox')
# 5                              51                                  None
# 6                              51                      StandardScaler()
# 7                              51                        MinMaxScaler()
# 8                              51  QuantileTransformer(n_quantiles=100)
# 9                              51    PowerTransformer(method='box-cox')
# 10                            101                                  None
# 11                            101                      StandardScaler()
# 12                            101                        MinMaxScaler()
# 13                            101  QuantileTransformer(n_quantiles=100)
# 14                            101    PowerTransformer(method='box-cox')
#
#                                                params  split0_test_score  \
# 0   {'classifier__n_neighbors': 5, 'preprocessor':...           0.742857
# 1   {'classifier__n_neighbors': 5, 'preprocessor':...           1.000000
# 2   {'classifier__n_neighbors': 5, 'preprocessor':...           1.000000
# 3   {'classifier__n_neighbors': 5, 'preprocessor':...           0.971429
# 4   {'classifier__n_neighbors': 5, 'preprocessor':...           1.000000
# 5   {'classifier__n_neighbors': 51, 'preprocessor'...           0.742857
# 6   {'classifier__n_neighbors': 51, 'preprocessor'...           0.971429
# 7   {'classifier__n_neighbors': 51, 'preprocessor'...           0.942857
# 8   {'classifier__n_neighbors': 51, 'preprocessor'...           0.914286
# 9   {'classifier__n_neighbors': 51, 'preprocessor'...           0.942857
# 10  {'classifier__n_neighbors': 101, 'preprocessor...           0.742857
# 11  {'classifier__n_neighbors': 101, 'preprocessor...           0.914286
# 12  {'classifier__n_neighbors': 101, 'preprocessor...           0.914286
# 13  {'classifier__n_neighbors': 101, 'preprocessor...           0.914286
# 14  {'classifier__n_neighbors': 101, 'preprocessor...           0.942857
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.800000           0.794118           0.794118
# 1            1.000000           1.000000           0.941176
# 2            0.971429           1.000000           0.970588
# 3            0.942857           1.000000           0.941176
# 4            0.971429           1.000000           0.911765
# 5            0.685714           0.735294           0.705882
# 6            0.971429           1.000000           0.911765
# 7            0.971429           1.000000           0.911765
# 8            0.971429           1.000000           0.911765
# 9            0.971429           1.000000           0.911765
# 10           0.714286           0.705882           0.705882
# 11           0.971429           0.970588           0.911765
# 12           0.914286           0.970588           0.911765
# 13           0.914286           0.882353           0.911765
# 14           0.942857           0.941176           0.941176
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.647059           0.764706           0.882353
# 1            0.911765           0.970588           0.970588
# 2            0.911765           0.941176           0.941176
# 3            0.941176           1.000000           0.970588
# 4            0.911765           0.970588           0.941176
# 5            0.647059           0.764706           0.735294
# 6            0.911765           0.970588           0.941176
# 7            0.882353           0.970588           0.911765
# 8            0.941176           0.941176           0.970588
# 9            0.882353           0.970588           0.911765
# 10           0.705882           0.764706           0.735294
# 11           0.882353           0.911765           0.882353
# 12           0.882353           0.911765           0.823529
# 13           0.823529           0.852941           0.823529
# 14           0.852941           0.882353           0.852941
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.794118           0.911765           0.852941         0.798403
# 1            0.941176           0.911765           0.970588         0.961765
# 2            0.970588           0.911765           0.970588         0.958908
# 3            0.941176           0.911765           0.970588         0.959076
# 4            0.941176           0.911765           1.000000         0.955966
# 5            0.735294           0.764706           0.764706         0.728151
# 6            0.970588           0.941176           0.970588         0.956050
# 7            0.970588           0.941176           0.941176         0.944370
# 8            0.941176           0.941176           0.970588         0.950336
# 9            0.970588           0.941176           0.941176         0.944370
# 10           0.735294           0.764706           0.794118         0.736891
# 11           0.911765           0.882353           0.941176         0.917983
# 12           0.941176           0.882353           0.941176         0.909328
# 13           0.882353           0.823529           0.911765         0.874034
# 14           0.911765           0.882353           0.911765         0.906218
#
#     std_test_score  rank_test_score
# 0         0.070751               13
# 1         0.032353                1
# 2         0.030028                3
# 3         0.026888                2
# 4         0.035452                5
# 5         0.036402               15
# 6         0.027209                4
# 7         0.033461                7
# 8         0.026181                6
# 9         0.033461                7
# 10        0.028738               14
# 11        0.031780                9
# 12        0.038287               10
# 13        0.037846               12
# 14        0.034650               11

# %%
cv_model_grid_search = pd.DataFrame(model_grid_search.cv_results_)

# %%
cv_model_grid_search.loc[cv_model_grid_search["param_preprocessor"] == all_preprocessors[1]]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1        0.002962      0.000347         0.002560        0.000297
# 6        0.002666      0.000257         0.002503        0.000309
# 11       0.002521      0.000070         0.002530        0.000115
#
#     param_classifier__n_neighbors param_preprocessor  \
# 1                               5   StandardScaler()
# 6                              51   StandardScaler()
# 11                            101   StandardScaler()
#
#                                                params  split0_test_score  \
# 1   {'classifier__n_neighbors': 5, 'preprocessor':...           1.000000
# 6   {'classifier__n_neighbors': 51, 'preprocessor'...           0.971429
# 11  {'classifier__n_neighbors': 101, 'preprocessor...           0.914286
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 1            1.000000           1.000000           0.941176
# 6            0.971429           1.000000           0.911765
# 11           0.971429           0.970588           0.911765
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 1            0.911765           0.970588           0.970588
# 6            0.911765           0.970588           0.941176
# 11           0.882353           0.911765           0.882353
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 1            0.941176           0.911765           0.970588         0.961765
# 6            0.970588           0.941176           0.970588         0.956050
# 11           0.911765           0.882353           0.941176         0.917983
#
#     std_test_score  rank_test_score
# 1         0.032353                1
# 6         0.027209                4
# 11        0.031780                9

# %% [markdown]
# #### > Using a StandardScaler, the best ranked model is NOT substantially better than any other

# %% [markdown]
# #### > Using any preprocessor indeed HAS better ranking than not using

# %%
cv_model_grid_search.loc[
    (
        cv_model_grid_search["param_preprocessor"] == all_preprocessors[1] # StdSclr
    )
        &
    (
        (
        cv_model_grid_search["param_classifier__n_neighbors"] == 5
        )
        |
        (
        cv_model_grid_search["param_classifier__n_neighbors"] == 51
        )
    )
]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1       0.002962      0.000347         0.002560        0.000297
# 6       0.002666      0.000257         0.002503        0.000309
#
#    param_classifier__n_neighbors param_preprocessor  \
# 1                              5   StandardScaler()
# 6                             51   StandardScaler()
#
#                                               params  split0_test_score  \
# 1  {'classifier__n_neighbors': 5, 'preprocessor':...           1.000000
# 6  {'classifier__n_neighbors': 51, 'preprocessor'...           0.971429
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1           1.000000                1.0           0.941176           0.911765
# 6           0.971429                1.0           0.911765           0.911765
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 1           0.970588           0.970588           0.941176           0.911765
# 6           0.970588           0.941176           0.970588           0.941176
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 1           0.970588         0.961765        0.032353                1
# 6           0.970588         0.956050        0.027209                4

# %% [markdown]
# #### > 5 + StdScaler is NOT subs. better than 51 + StdScaler

# %%
cv_model_grid_search.loc[
    (
        cv_model_grid_search["param_preprocessor"] == all_preprocessors[1] # StdSclr
    )
        &
    (
        (
        cv_model_grid_search["param_classifier__n_neighbors"] == 51
        )
        |
        (
        cv_model_grid_search["param_classifier__n_neighbors"] == 101
        )
    )
]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6        0.002666      0.000257         0.002503        0.000309
# 11       0.002521      0.000070         0.002530        0.000115
#
#     param_classifier__n_neighbors param_preprocessor  \
# 6                              51   StandardScaler()
# 11                            101   StandardScaler()
#
#                                                params  split0_test_score  \
# 6   {'classifier__n_neighbors': 51, 'preprocessor'...           0.971429
# 11  {'classifier__n_neighbors': 101, 'preprocessor...           0.914286
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 6            0.971429           1.000000           0.911765
# 11           0.971429           0.970588           0.911765
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 6            0.911765           0.970588           0.941176
# 11           0.882353           0.911765           0.882353
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 6            0.970588           0.941176           0.970588         0.956050
# 11           0.911765           0.882353           0.941176         0.917983
#
#     std_test_score  rank_test_score
# 6         0.027209                4
# 11        0.031780                9

# %% [markdown]
# #### > 51 + StdScaler indeed IS subs. better than 101 + StdScaler

# %% [markdown]
# # Q6

# %%
from sklearn.model_selection import cross_validate

cv_results_nested = cross_validate(
    model_grid_search,
    data,
    target,
    cv=10,
    return_estimator=True,
    scoring="balanced_accuracy"
)

# %%
cv_results_nested['test_score'].mean()
# Out:
# np.float64(0.9370940170940172)

# %% [markdown]
# # Q7

# %%
estimator = cv_results_nested['estimator']

# %%
for cv_fold, estimator_in_fold in enumerate(estimator):
    print(
        f"Best hyperparameters for fold #{cv_fold + 1}:\n"
        f"{estimator_in_fold.best_params_}"
    )
# Out:
# Best hyperparameters for fold #1:
# {'classifier__n_neighbors': 5, 'preprocessor': QuantileTransformer(n_quantiles=100)}
# Best hyperparameters for fold #2:
# {'classifier__n_neighbors': 5, 'preprocessor': QuantileTransformer(n_quantiles=100)}
# Best hyperparameters for fold #3:
# {'classifier__n_neighbors': 5, 'preprocessor': StandardScaler()}
# Best hyperparameters for fold #4:
# {'classifier__n_neighbors': 51, 'preprocessor': StandardScaler()}
# Best hyperparameters for fold #5:
# {'classifier__n_neighbors': 51, 'preprocessor': StandardScaler()}
# Best hyperparameters for fold #6:
# {'classifier__n_neighbors': 5, 'preprocessor': QuantileTransformer(n_quantiles=100)}
# Best hyperparameters for fold #7:
# {'classifier__n_neighbors': 5, 'preprocessor': MinMaxScaler()}
# Best hyperparameters for fold #8:
# {'classifier__n_neighbors': 5, 'preprocessor': StandardScaler()}
# Best hyperparameters for fold #9:
# {'classifier__n_neighbors': 5, 'preprocessor': StandardScaler()}
# Best hyperparameters for fold #10:
# {'classifier__n_neighbors': 5, 'preprocessor': QuantileTransformer(n_quantiles=100)}
