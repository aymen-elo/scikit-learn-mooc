# %% [markdown]
# # 📝 Exercise M1.01

# %% [markdown]
# Imagine we are interested in predicting penguins species based on two of their
# body measurements: culmen length and culmen depth. First we want to do some
# data exploration to get a feel for the data.
#
# What are the features? What is the target?

# %% [markdown]
# The data is located in `../datasets/penguins_classification.csv`, load it with
# `pandas` into a `DataFrame`.

# %%
import pandas as pd

penguins_classification = pd.read_csv('../datasets/penguins_classification.csv')

# %% [markdown]
# Show a few samples of the data.
#
# How many features are numerical? How many features are categorical?

# %%
penguins_classification.head()
# Numerical features: 2
# Categorical features: 1
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %% [markdown]
# What are the different penguins species available in the dataset and how many
# samples of each species are there? Hint: select the right column and use the
# [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
# method.

# %%
# Write your code here.
target_column = 'Species' 
penguins_classification[target_column].value_counts()
# Species: 3
# Samples shown in the result below :
# Out:
# Species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# Plot histograms for the numerical features

# %%
penguins_classification_numerical = penguins_classification[["Culmen Length (mm)", "Culmen Depth (mm)"]]
_ = penguins_classification_numerica.hist() # Note: no need to manually remove the categorical data

# %% [markdown]
# Show features distribution for each class. Hint: use
# [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
import seaborn as sb

numerical_features = ['Culmen Length (mm)', 'Culmen Depth (mm)']

_ = sb.pairplot(
    data=penguins_classification,
    vars=numerical_features,
    hue=target_column,
    plot_kws={"alpha": 0.2},
    height=3,
    diag_kind="hist",
    diag_kws={"bins": 30},
)

# %% [markdown]
# Looking at these distributions, how hard do you think it would be to classify
# the penguins only using `"culmen depth"` and `"culmen length"`?

# %% [markdown]
# ### Answer
# The data looks pretty well separated to to be able to identify species separately by Cumen Depth and Length:
# - Adelie: Low CL
# - Gentoo: Low CD
# - Chinstrap: High CL and High CD
